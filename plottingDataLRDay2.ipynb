# %% [markdown]
# <a href="https://colab.research.google.com/github/NIKKISAHA/dataStructure/blob/main/plottingDataLRDay2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.optimize import linear_sum_assignment
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import pickle
from matplotlib import style

data =pd.read_csv("/content/sample_data/california_housing_test.csv")
# data.head(5)

data = data[["longitude","latitude","housing_median_age","households","population"]]
pridict= "population"
# data

x=np.array(data.drop([pridict],1))
y=np.array(data[pridict])
# x
# y

x_train,x_test,y_train,y_test = sklearn.model_selection.train_test_split(x,y,test_size=0.1)

# best =0
# for i in range(50):
#   x_train,x_test,y_train,y_test = sklearn.model_selection.train_test_split(x,y,test_size=0.1)
#   linear=linear_model.LinearRegression()
#   linear.fit(x_train,y_train)
#   acc= linear.score(x_test,y_test)
#   # acc
#   if acc > best:
#     best = acc
#     with open("rikiLinearRegression.pickle","wb")as f:
      # pickle.dump(linear,f)


pickle_in = open("/content/rikiLinearRegression.pickle","rb")
linear= pickle.load(pickle_in)

# linear.coef_
# linear.intercept_

# p=linear.predict(x_test)
# for i in range(len(p)):
#   print(p[i],x_test[i],y_test[i])

p="latitude"
style.use("ggplot")
plt.scatter(data[p],data["population"])
plt.xlabel(p)
plt.ylabel("population")
plt.show()
# Out:
# <ipython-input-13-acd1d2fa80d3>:18: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x=np.array(data.drop([pridict],1))
