# %% [markdown]
# <a href="https://colab.research.google.com/github/NIKKISAHA/dataStructure/blob/main/day2numpyml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
mydata=["car","bike","cycle","airplane"]
# pd.Series(mydata)
mydata2=[("car",1),("bike",0),("cycle",2),("airplane",3)]
new=pd.DataFrame(mydata2,columns=["v","num"])
new.dtypes
# new.head()
new.describe()
# Out:
#             num
# count  4.000000
# mean   1.500000
# std    1.290994
# min    0.000000
# 25%    0.750000
# 50%    1.500000
# 75%    2.250000
# max    3.000000
